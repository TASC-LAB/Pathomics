# %%
from tkinter import *
from tkinter import ttk
from tkinter.ttk import Progressbar
from tkinter.ttk import Combobox
from tkinter.ttk import Notebook
from tkinter import filedialog as fd
from tkinter import messagebox
from tkinter.messagebox import showinfo
import tkinter as tk
import tkinter.font
import numpy as np
import pandas as pd 
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.stats import zscore
from sklearn import decomposition
from IPython.display import display, Latex
from sklearn.cluster import KMeans
import pickle
import sklearn.cluster as cluster
from pathlib import Path
import os
import glob
from tqdm import tqdm_notebook
from lifelines.plotting import plot_lifetimes
from lifelines import KaplanMeierFitter
from lifelines import CoxPHFitter
from lifelines.statistics import logrank_test
from lifelines.statistics import multivariate_logrank_test
from lifelines.statistics import pairwise_logrank_test
import IPython.display as display
from PIL import ImageTk, Image
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
from utils1  import *
from collections import Counter
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import csv
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
#from norma  import *
from tkinter import filedialog
import tkinter.messagebox
import time

# %%
class Homepage():
    def __init__(self, parent):
        self.gui(parent)

    def gui(self, parent):
        if parent == 0:
            self.w1 = Tk()
            self.w1.configure(bg = '#c0d3ff')
            self.w1.geometry('2000x2000')
            self.w1.title("Pathomics 3 Homepage")
        else:
            self.w1 = Frame(parent)
            self.w1.configure(bg = '#c0d3ff')
            self.w1.place(x = 0, y = 0, width = 500, height = 500)
        
        
        
        self.bg_image = ImageTk.PhotoImage(file =r'C:\Users\user\Documents\itamar\GUI\logo.png')
        x = Label (image = self.bg_image)
        x.grid(row = 0, column = 0)
        
        #canvas = Canvas(width=10, height=10)
        #canvas.pack(expand= True, fill="both")
        #self.image = ImageTk.PhotoImage(file=r'C:\Users\user\Documents\itamar\GUI\logo.png')
        #canvas.create_image(10, 10, image=self.image, anchor=NW)


        
        self.button1 = Button(self.w1, text = "Input the single nucleus features per image", bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 14), cursor = "arrow", state = "normal")
        self.button1.place(x = 500, y = 10, width = 400, height = 100)
        self.button1['command'] = self.Features_list
        self.button2 = Button(self.w1, text = "Mice Clinical data input", bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 16), cursor = "arrow", state = "normal")
        self.button2.place(x = 500, y = 110, width = 400, height = 100)
        self.button2['command'] = self.Mice_data
        self.button4 = Button(self.w1, text = "Data Analysis - Boruta, Kmeans and PCA", bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 16), cursor = "arrow", state = "normal")
        self.button4.place(x = 500, y = 310, width = 400, height = 100)
        self.button4['command'] = self.analyze
        self.button5 = Button(self.w1, text = "To results", bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button5.place(x = 780, y = 510, width = 120, height = 30)
        self.button5['command'] = self.to_results
        self.button5 = Button(self.w1, text = "Data preprocessing", bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 16), cursor = "arrow", state = "normal")
        self.button5.place(x = 500, y = 210, width = 400, height = 100)
        self.button5['command'] = self.clean_data
        #self.ltext1 = Entry(self.w1, bg = "#ffffff", fg = "#000000", font = tkinter.font.Font(family = "Rockwell", size = 20), cursor = "arrow", state = "normal")
        #self.ltext1.place(x = 170, y = 0, width = 160, height = 32)
        #self.ltext1.insert(INSERT, "Pathomics 3")
        
    
    def Mice_data(self):
        root=tk.Toplevel()
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        filetypes=(('text files', '*.txt'), ('All files', '*.*'),('Excel files', '*.xls'),('CSV files','*.csv')) 
        filename=fd.askopenfilename(initialdir = '/', filetypes = filetypes)
        file=pd.read_csv(filename)#here will be directory for intermediate file, 
        file.to_csv(os.path.join(folder, 'mice.csv')) 
        tkinter.messagebox.showinfo("Pathomics 3", "Mice_file selected")

    def analyze(self):
        root=tk.Toplevel()
        self.my_progress= ttk.Progressbar(root, orient=HORIZONTAL, length= 400, mode= 'determinate')
        self.my_progress.start(10)
        self.my_progress.pack(anchor='se')
        def zScoreEach(data):
            for col in data.columns:
                data[col] = zscore(data[col]).astype(float)
            return data
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        label = 'Mouse' #define desired label here
        if label == 'Line':
            rawdf = pd.concat([rawlabels['Line'],rawdata],axis=1)
            rawdf = rawdf[rawdf.Line != '0000']
            rawlabels = rawlabels[rawlabels.Line != '0000']
            rawdf.drop('Line',axis=1, inplace=True)
            rawdata = rawdf.copy()
            rawdata.to_pickle(os.path.join(folder, 'rawdata_line.pickle')) 
            rawlabels.to_pickle(os.path.join(folder, 'rawlabel_line.pickle'))
        if label == 'Line':
            rawdata = pd.read_pickle(os.path.join(folder,'rawdata_line.pickle')) #Change to rawdata_line if running Line
            rawlabel = pd.read_pickle(os.path.join(folder,'rawlabel_line.pickle')) 
        else:    
            rawdata = pd.read_pickle(os.path.join(folder,'rawdata.pickle'))  
            rawlabel = pd.read_pickle(os.path.join(folder,'rawlabel.pickle'))
        
        # rawdata = pd.read_pickle(os.path.join(folder,'rawdata_line.pickle')) #Change to rawdata_line if running Line
        rawdatacopy = rawdata.copy()
        zscore_rawdata = zScoreEach(rawdatacopy)
        rawlabel = pd.read_pickle(os.path.join(folder,'rawlabel.pickle'))
        # rawlabel = pd.read_pickle(os.path.join(folder,'rawlabel_line.pickle')) #Change to rawlabels_line if running Line
        
        #self.my_progress= ttk.Progressbar(self.w1, orient=HORIZONTAL, length= 400, mode= 'determinate')
        #self.my_progress.pack()
        #self.my_progress.start(10)
        my_list = zscore_rawdata.columns.values.tolist() 
        X = zscore_rawdata[my_list].values
        X = pd.DataFrame(X).fillna(value=0).values
        y = rawlabel[label].values.ravel() 
       
        
        # define random forest classifier, with utilising all cores and
        # sampling in proportion to y labels
        rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
    
        # define Boruta feature selection method
        feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=1)

        # find all relevant features - 5 features should be selected
        feat_selector.fit(X, y)

        # check selected features - first 5 features are selected
        feat_selector.support_

        # check ranking of features
        feat_selector.ranking_

        final_features = list()
        indexes = np.where(feat_selector.support_ == True)
        for x in np.nditer(indexes):
            final_features.append(my_list[x])
    
        pic = rawdata[final_features]
        piclabels = rawlabel.copy()
       
        with open(os.path.join(folder, 'pic.pickle'), "wb") as f:
            pickle.dump((pic,piclabels), f)
 
        with open(os.path.join(folder, 'pic.pickle'), "rb") as f: #Include the '_line' if you are running Line/QTL analysis!
            rawdata,rawlabels = pickle.load(f) 
  
        features = rawdata.columns.values.tolist()
        Groups = 'Mouse'
        pca_df,pca,pca_transformed = pcaCalcOneExp(zScoreEach(rawdata),rawlabels[Groups],'PCA',-1,nColor=0,nShades=0)
        K=range(1,12)
        wss = []
        for k in K:
            kmeans=cluster.KMeans(n_clusters=k,init="k-means++")
            kmeans=kmeans.fit(rawdata)
            wss_iter = kmeans.inertia_
            wss.append(wss_iter)
                
        max=0
        clusters=0
        for i in range(3,13):
            labels=cluster.KMeans(n_clusters=i,init="k-means++",random_state=200).fit(rawdata).labels_
            if max < metrics.silhouette_score(rawdata,labels,metric="euclidean",sample_size=1000,random_state=200):
                     max= metrics.silhouette_score(rawdata,labels,metric="euclidean",sample_size=1000,random_state=200)
                     num_of_clusters=i
        print(num_of_clusters)    
        kmeans_pca,xlim_kmeans,ylim_kmeans = kmeansPlot(num_of_clusters,pca_transformed,pca,rawlabels[Groups])
        kmeans_pca.to_csv(os.path.join(folder,'kmeans_pca.csv'))
        rawlabels.to_pickle(os.path.join(folder, 'rawlabel_line.pickle'))
        self.my_progress.stop()
        tkinter.messagebox.showinfo("Pathomics 3", "Analysis complete, you may proceed to results")
    def Features_list(self):
        #self.w1.destroy()
        directory = filedialog.askdirectory()
        #directory = input("Enter the path of your folder:")
        read_files = glob.glob(directory + "/*.txt")
        average_all = pd.DataFrame([])
        list1 = []
        for file in read_files:
            df = pd.read_csv(file, sep = '\t')
            image = df.iloc[0,0]
            numbers = df.iloc[:,5:]
            average = numbers.mean(axis = 0, skipna = False)
            df_average = pd. DataFrame([average])
            df_average.insert(0,'Image', image)
            average_all = pd.concat([average_all, df_average])

        average_all.set_index("Image",inplace=True)
        folder_name = 'Results_GUI'
        folder = os.path.join(directory, folder_name)
        if os.path.exists(folder):
            os.makedirs(folder)
        #important to change the path in the line of code below up until results, which means (results/Summary_Table.csv')
        # should be added to the path inputed
        average_all.to_csv(r'C:\Users\user\Documents\itamar\GUI\summary_table_GUI.csv') #change to desired path

    def to_results(self):
        self.w1.destroy()
        a=Analysis_page(0)
        a.w1.mainloop()
    
    def clean_data(self):
        root=tk.Toplevel()
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        data_file = pd.read_csv(os.path.join(folder, 'summary_table_GUI.csv')) #Summary table file name
        rawdata = data_file.iloc[:,1:]
        rawdata.to_pickle(os.path.join(folder, 'rawdata.pickle'))
        rawdata = pd.read_pickle(os.path.join(folder, 'rawdata.pickle'))
        rawdata.to_csv(r'C:\Users\user\Documents\itamar\GUI\Test1.csv')
        labels = data_file = data_file.iloc[:,:1]
        mousedata = {'Mouse':data_file['Image'].str[2:6]} #Gets the mouse characters from the 32 character code in a seperate vector 
        linedata = {'Line':data_file['Image'].str[21:25]}
        slicedata = {'Series':data_file['Image'].str[38:47]}
        posdata = {'Patch Position (X_Y)':data_file['Image'].str[48:]}
        codedata = {'CodeSeries':data_file['Image'].str[:47]}
        Mouse = pd.DataFrame(mousedata)
        Lines = pd.DataFrame(linedata)
        Slice = pd.DataFrame(slicedata)
        Position = pd.DataFrame(posdata)
        Code = pd.DataFrame(codedata)
        Position['Patch Position (X_Y)'] = Position['Patch Position (X_Y)'].str.replace('.png.png.txt', '')
        labels = pd.concat([Mouse,Lines,Slice,Code,data_file['Image']],axis = 1)
        
        X_ROI = []
        Y_ROI = []

        for i in Position['Patch Position (X_Y)']:
            d= i.split('_',1)
            xroi = int(d[0])
            yroi = int(d[1])
            X_ROI.append(xroi)
            Y_ROI.append(yroi)
        labels = labels.reset_index()
        labels = pd.concat([labels,pd.DataFrame(X_ROI, columns=["X_ROI"]), pd.DataFrame(Y_ROI, columns=["Y_ROI"])],axis = 1)
        del labels['index']
        labels.to_pickle(os.path.join(folder, 'rawlabel.pickle'))
        rawlabels = pd.read_pickle(os.path.join(folder, 'rawlabel.pickle'))
        #T = Text(root, height = 0, width = 30)
        #l = Label(root, text = "Data Preprocessing Complete",bg='blue')
        #l.config(font =("Courier", 15))
        #T.pack(pady = 10)
        #l.pack()
        tkinter.messagebox.showinfo("Pathomics 3", "Pre-processing complete, you may proceed to analysis")
        

    
class Analysis_page():
    def __init__(self, parent):
        self.gui(parent)
        self.parent=parent


    def gui(self, parent):
        if parent == 0:
            self.w1 = Tk()
            self.w1.configure(bg = '#c0d3ff')
            self.w1.geometry('2000x2000')
            self.w1.title("Pathomics 3 results")
        else:
            self.w1 = Frame(parent)
            self.w1.configure(bg = '#c0d3ff')
            self.w1.place(x = 0, y = 0, width = 1200, height = 1000)
        self.button2 = Button(self.w1, text = "Kaplan Meir Graph", bg = "#ffffff", fg = "#0b0b0b", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button2.place(x = 160, y = 60, width = 200, height = 42)
        self.button2['command']= self.Kaplan_Meier_graph 
        self.button3 = Button(self.w1, text = "Anova table ", bg = "#ffffff", fg = "#060606", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button3.place(x = 160, y = 140, width = 200, height = 42)
        self.button3['command']= self.Anova_table 
        self.button4 = Button(self.w1, text = "Cox Analysis", bg = "#ffffff", fg = "#060606", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button4.place(x = 160, y = 220, width = 200, height = 42)
        self.button4['command']= self.Cox_analysis
        self.button5 = Button(self.w1, text = "Feature distribution groups ", bg = "#ffffff", fg = "#060606", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button5.place(x = 160, y = 300, width = 200, height = 42)
        self.button5['command']= self.Feature_distribution_groups
        self.button5 = Button(self.w1, text = "Home", bg = "#ffffff", fg = "#080808", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button5.place(x = 30, y = 350, width = 90, height = 32)
        self.button5['command']=self.Home
        self.button6 = Button(self.w1, text = "Clear page", bg = "#ffffff", fg = "#080808", font = tkinter.font.Font(family = "Rockwell", size = 10), cursor = "arrow", state = "normal")
        self.button6.place(x = 30, y = 310, width = 90, height = 32)
        self.button6['command']=self.clear_frame
    def Home(self):
        self.w1.destroy()
        a=Homepage(0)
        a.w1.mainloop()
    def Kaplan_Meier_graph(self):
        Groups='Mouse'
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        with open(os.path.join(folder, 'pic.pickle'), "rb") as f: #Include the '_line' if you are running Line/QTL analysis!
            rawdata,rawlabels = pickle.load(f) 
        array = rawlabels[Groups]
        labels = list(array)
        kmeans_pca=pd.read_csv(os.path.join(folder,'kmeans_pca.csv'))
        kgroups = kmeans_pca['Groups']
        pred = list(kgroups)
        a = dict(Counter(array))
        df = pd.DataFrame({'Labels': labels, 'Clusters': pred})
        ct = pd.crosstab(df['Labels'], df['Clusters'],normalize = 'index')
        fig, ax = plt.subplots(figsize=(20,10))         
        sns.heatmap(ct, annot=True)
        ax.set_ylim([len(np.unique(array)),0])
        for t in ax.texts: t.set_text(math.floor(float(t.get_text())*100))
        for t in ax.texts: t.set_text((t.get_text()) + "%")
        KM_filename = 'ByGroups_QTL3.csv'
        with open(os.path.join(folder, KM_filename),'w') as outfile:
            ct.to_csv(outfile, header=True)
        plt.savefig(os.path.join(folder,'Confusion matrix.png'))
        plt.clf()
        data2=pd.read_csv(os.path.join(folder, 'ByGroups_QTL3.csv'))
        data2['Age']=0
        data2['L/D']=1
        data1= pd.read_csv(os.path.join(folder, 'mice.csv'))
        for i in range(len(data2)):
            for j in range(len(data1)):
                if data2['Labels'][i]==data1['Mouse'][j]:
                    data2['Age'][i]=data1['Age'][j]
                    data2['L/D'][i]=data1['L/D'][j]
                    j+=1
            i+=1
        data2=data2[data2['Age']>0]
        data2=data2.reset_index()
        data3=data2.drop(["Labels","Age","L/D"],axis=1)
        data3=data3.drop(["index"],axis=1)
        data3['Max']=data3.max(axis=1)
        for i in range (3): 
            for j in range(len(data2)):
                if data2[str(i)][j]>=data3['Max'][j]:  #Threshold needs to be optimized
                    data2[str(i)][j]=1
                else:
                    data2[str(i)][j]=0
                j+=1
            i+=1
        to_groups(data2)
        kmf = KaplanMeierFitter() 
        T=data2['Age']
        headings=data2.columns.tolist()
        for i in range(len(headings)-5):
            kmf.fit(T,data2[headings[i+2]],label=headings[i+2]+' (n=%d)'%data2[headings[i+2]].tolist().count(1))
            kmf.plot(linewidth=3.0)
            i+=1
        figure = plt.gcf()
        figure.set_size_inches(10,6)
        plt.title('Survival Function of Mice Within Groups');
        plt.xlabel('Months')
        data2.to_csv(os.path.join(folder,'Kaplan meier data.csv'))
        results = multivariate_logrank_test(data2['Age'], data2['Groups'], data2['L/D'],weightings = 'wilcoxon') #log rank analysis
        plt.text(0.5,0.3,'p value = '+str(results.p_value),color='b',font='bold')
        plt.savefig(os.path.join(folder,'Kaplan meier graph.png'))
        self.photo2=tk.PhotoImage(file=(r'C:\Users\user\Documents\itamar\GUI\Kaplan meier graph.png'))
        label2=tk.Label(self.w1,image=self.photo2,width= 600,height=400)
        label2.pack(side=TOP)
    def clear_frame(self):
        self.w1.winfo_children()[6].destroy()
        self.w1.winfo_children()[7].destroy()
        self.w1.winfo_children()[8].destroy()
        
    def Cox_analysis(self):
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        data_cox=pd.read_csv(os.path.join(folder,'Kaplan meier data.csv'))
        for i in range(len(data_cox)):
            if data_cox['Groups'][i]== 'A':
                data_cox['Groups'][i]= 1
            if data_cox['Groups'][i]== 'B':
                data_cox['Groups'][i]= 2
            if data_cox['Groups'][i]== 'C':
                data_cox['Groups'][i]= 3
            if data_cox['Groups'][i]== 'Ignore':
                data_cox['Groups'][i]= 0
        data_cox=data_cox.drop(['Unnamed: 0','index'],axis=1)
        print(data_cox)
            #if data_cox['Groups'][i]== 'D':
                #data_cox['Groups'][i]= 4
    #if data_cox['Groups'][i]== 'E':
        #data_cox['Groups'][i]= 5
    #if data_cox['Groups'][i]== 'F':
        #data_cox['Groups'][i]= 6
   # One may add these in dependednt on the optimal ammount of clusters
        cph=CoxPHFitter(penalizer=0.1)
        cph.fit(data_cox,'Age',event_col='L/D',show_progress=True)
        cph.print_summary()
        tkinter.messagebox.showinfo("Pathomics 3", "Cox analysis results in command line")
    def Feature_distribution_groups(self):
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        rawdata=pd.read_pickle(os.path.join(folder,'rawdata.pickle'))
        features = rawdata.columns.values.tolist()
        rawdata.reset_index(drop=True, inplace=True)
        rawlabels=pd.read_pickle(os.path.join(folder,'rawlabel.pickle'))
        rawlabels.reset_index(drop=True, inplace=True)
        kmeans_pca=pd.read_csv(os.path.join(folder,'kmeans_pca.csv'))
        kmeans_pca['Groups'].reset_index(drop=True, inplace=True)
        raw2 = pd.concat([rawdata,rawlabels,kmeans_pca['Groups']],axis =1)
        Groups = 'Groups'
        histogramDataKDELabels(range(3),raw2,features,0,Par=Groups,nColor=0, nShades=0)
    def Anova_table(self):
        folder = (r'C:\Users\user\Documents\itamar\GUI')#here put in path of intermediate folder
        rawdata=pd.read_pickle(os.path.join(folder,'rawdata.pickle'))
        features = rawdata.columns.values.tolist()
        kmeans_pca=pd.read_csv(os.path.join(folder,'kmeans_pca.csv'))
        rawdata.reset_index(drop=True, inplace=True)
        kmeans_pca.reset_index(drop=True, inplace=True)
        raw3 = pd.concat([rawdata,kmeans_pca],axis=1)
        Data_anov=ANOVE_DESC_TABLE(raw3,features,title='Sarcoma Mouse 3 Groups',dep = 'Groups',groupList =['Group A','Group B','Group C',]) #Change groupList based on your num_of_clusters 
        Data_anov.to_excel(os.path.join(folder,'Anova table.xlsx'))
        Data_anov.insert(0, "Features", Data_anov.index)
        anova_frame=Frame(self.w1)
        style=ttk.Style()
        style.configure("Treeview",background="grey",foreground="black",rowheight=30,colheight=500)
        anova_frame.pack(side=BOTTOM,pady=55,padx=40)
        tree_scrollx=Scrollbar(anova_frame,orient='horizontal')
        tree_scrollx.pack(side=BOTTOM,fill=X)
        tree_scrolly=Scrollbar(anova_frame)
        tree_scrolly.pack(side=RIGHT,fill=Y)
        tv1=ttk.Treeview(anova_frame,yscrollcommand=tree_scrolly.set,xscrollcommand=tree_scrollx.set)
        tv1.place(relheight=50, relwidth=20)
        tv1["column"]=list(Data_anov.columns)
        tv1["show"]="headings"
        for column in tv1["column"]:
            tv1.heading(column, text=column)
        df_rows=Data_anov.to_numpy().tolist()
        for row in df_rows:
            tv1.insert("","end",values=row)
        tree_scrolly.config(command=tv1.yview)
        tree_scrollx.config(command=tv1.xview)
        tv1.pack(side=BOTTOM,padx=35,pady=5)
        root.mainloop()
    
a = Homepage(0)
a.w1.mainloop()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:202: FutureWarning: The default value of regex will change from True to False in a future version.
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	495
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	413
# Tentative: 	82
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	413
# Tentative: 	82
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	413
# Tentative: 	82
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	413
# Tentative: 	82
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	428
# Tentative: 	67
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	428
# Tentative: 	67
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	428
# Tentative: 	66
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	428
# Tentative: 	66
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	436
# Tentative: 	58
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	436
# Tentative: 	58
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	436
# Tentative: 	57
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	441
# Tentative: 	52
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	441
# Tentative: 	52
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	441
# Tentative: 	52
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	446
# Tentative: 	47
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	446
# Tentative: 	47
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	446
# Tentative: 	47
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	446
# Tentative: 	47
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	453
# Tentative: 	40
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	453
# Tentative: 	40
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	453
# Tentative: 	40
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	456
# Tentative: 	37
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	456
# Tentative: 	37
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	456
# Tentative: 	37
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	457
# Tentative: 	36
# Rejected: 	2
# Iteration: 	33 / 100
# Confirmed: 	457
# Tentative: 	36
# Rejected: 	2
# Iteration: 	34 / 100
# Confirmed: 	460
# Tentative: 	33
# Rejected: 	2
# Iteration: 	35 / 100
# Confirmed: 	460
# Tentative: 	33
# Rejected: 	2
# Iteration: 	36 / 100
# Confirmed: 	460
# Tentative: 	33
# Rejected: 	2
# Iteration: 	37 / 100
# Confirmed: 	462
# Tentative: 	31
# Rejected: 	2
# Iteration: 	38 / 100
# Confirmed: 	462
# Tentative: 	31
# Rejected: 	2
# Iteration: 	39 / 100
# Confirmed: 	462
# Tentative: 	31
# Rejected: 	2
# Iteration: 	40 / 100
# Confirmed: 	463
# Tentative: 	30
# Rejected: 	2
# Iteration: 	41 / 100
# Confirmed: 	463
# Tentative: 	30
# Rejected: 	2
# Iteration: 	42 / 100
# Confirmed: 	463
# Tentative: 	30
# Rejected: 	2
# Iteration: 	43 / 100
# Confirmed: 	465
# Tentative: 	27
# Rejected: 	3
# Iteration: 	44 / 100
# Confirmed: 	465
# Tentative: 	27
# Rejected: 	3
# Iteration: 	45 / 100
# Confirmed: 	465
# Tentative: 	27
# Rejected: 	3
# Iteration: 	46 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	51 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	52 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	53 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	54 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	55 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	56 / 100
# Confirmed: 	465
# Tentative: 	26
# Rejected: 	4
# Iteration: 	57 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	58 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	59 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	60 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	61 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	62 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	466
# Tentative: 	25
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	66 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	67 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	68 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	69 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	70 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	71 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	72 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	73 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	74 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	75 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	76 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	77 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	78 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	79 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	80 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	81 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	82 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	83 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	84 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	85 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	86 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	87 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	88 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	89 / 100
# Confirmed: 	466
# Tentative: 	24
# Rejected: 	5
# Iteration: 	90 / 100
# Confirmed: 	467
# Tentative: 	23
# Rejected: 	5
# Iteration: 	91 / 100
# Confirmed: 	467
# Tentative: 	23
# Rejected: 	5
# Iteration: 	92 / 100
# Confirmed: 	467
# Tentative: 	23
# Rejected: 	5
# Iteration: 	93 / 100
# Confirmed: 	467
# Tentative: 	23
# Rejected: 	5
# Iteration: 	94 / 100
# Confirmed: 	467
# Tentative: 	23
# Rejected: 	5
# Iteration: 	95 / 100
# Confirmed: 	467
# Tentative: 	22
# Rejected: 	6
# Iteration: 	96 / 100
# Confirmed: 	467
# Tentative: 	22
# Rejected: 	6
# Iteration: 	97 / 100
# Confirmed: 	467
# Tentative: 	22
# Rejected: 	6
# Iteration: 	98 / 100
# Confirmed: 	467
# Tentative: 	22
# Rejected: 	6
# Iteration: 	99 / 100
# Confirmed: 	467
# Tentative: 	22
# Rejected: 	6
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	467
# Tentative: 	15
# Rejected: 	6
# $\color{blue}{\Large Figure\ -1}$
# $\color{blue}{\Large Figure\ 0}$
# There are 2 signficant components
# 3
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:939: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 0.25.
#   " removed in 0.25.", FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Documents\itamar\GUI\utils1.py:569: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Groups"][i]= 'B'
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# findfont: Font family ['bold'] not found. Falling back to DejaVu Sans.
# $\color{blue}{\Large ANOVA\ Table\ feature\ per\ Group}$
#                                                Sig.  Groups               \
#                                                     Group A
#                                                           N         Mean
# Feature
# CentroidXPx                            8.860347e-01   367.0   999.485303
# CentroidYPx                            7.675554e-01   367.0   999.178465
# Nucleus_Area                           1.240871e-28   367.0    603.73792
# Nucleus_Perimeter                      4.346151e-45   367.0    98.117373
# Nucleus_Circularity                    4.025722e-60   367.0     0.781559
# ...                                             ...     ...          ...
# ClusterMean_Delaunay_MedianDistance    8.679812e-97   367.0     61.77979
# ClusterMean_Delaunay_MaxDistance       3.473369e-88   367.0   105.322888
# ClusterMean_Delaunay_MinDistance       1.692211e-71   367.0    35.575965
# ClusterMean_Delaunay_MeanTriangleArea  2.553327e-77   367.0  1697.235997
# ClusterMean_Delaunay_MaxTriangleArea   1.608971e-68   367.0  3474.898701
#
#                                                           \
#
#                                       Standard Deviation
# Feature
# CentroidXPx                                   108.313058
# CentroidYPx                                   110.251369
# Nucleus_Area                                   67.425769
# Nucleus_Perimeter                               6.602749
# Nucleus_Circularity                             0.028943
# ...                                                  ...
# ClusterMean_Delaunay_MedianDistance             9.181156
# ClusterMean_Delaunay_MaxDistance               22.457962
# ClusterMean_Delaunay_MinDistance                2.677857
# ClusterMean_Delaunay_MeanTriangleArea         703.788096
# ClusterMean_Delaunay_MaxTriangleArea         1885.782886
#
#                                                                 \
#
#                                       Standard Deviation Error
# Feature
# CentroidXPx                                           5.653896
# CentroidYPx                                           5.755075
# Nucleus_Area                                          3.519597
# Nucleus_Perimeter                                     0.344661
# Nucleus_Circularity                                   0.001511
# ...                                                        ...
# ClusterMean_Delaunay_MedianDistance                   0.479252
# ClusterMean_Delaunay_MaxDistance                      1.172296
# ClusterMean_Delaunay_MinDistance                      0.139783
# ClusterMean_Delaunay_MeanTriangleArea                 36.73744
# ClusterMean_Delaunay_MaxTriangleArea                 98.437065
#
#                                                             \
#
#                                       95% Upper Bound Mean
# Feature
# CentroidXPx                                    1010.551831
# CentroidYPx                                    1010.443033
# Nucleus_Area                                    610.626924
# Nucleus_Perimeter                                98.791987
# Nucleus_Circularity                               0.784516
# ...                                                    ...
# ClusterMean_Delaunay_MedianDistance              62.717844
# ClusterMean_Delaunay_MaxDistance                107.617455
# ClusterMean_Delaunay_MinDistance                 35.849566
# ClusterMean_Delaunay_MeanTriangleArea          1769.143211
# ClusterMean_Delaunay_MaxTriangleArea           3667.572313
#
#                                                                     \
#                                                            Group B
#                                       95% Lower Bound Mean       N
# Feature
# CentroidXPx                                     988.418776   400.0
# CentroidYPx                                     987.913897   400.0
# Nucleus_Area                                    596.848915   400.0
# Nucleus_Perimeter                                97.442759   400.0
# Nucleus_Circularity                               0.778602   400.0
# ...                                                    ...     ...
# ClusterMean_Delaunay_MedianDistance              60.841735   400.0
# ClusterMean_Delaunay_MaxDistance                 103.02832   400.0
# ClusterMean_Delaunay_MinDistance                 35.302364   400.0
# ClusterMean_Delaunay_MeanTriangleArea          1625.328782   400.0
# ClusterMean_Delaunay_MaxTriangleArea           3282.225088   400.0
#
#                                                                        \
#
#                                               Mean Standard Deviation
# Feature
# CentroidXPx                            1002.515621          72.570337
# CentroidYPx                            1002.112355          65.950046
# Nucleus_Area                            566.088647          87.238504
# Nucleus_Perimeter                        95.140499           7.537776
# Nucleus_Circularity                       0.778792           0.030485
# ...                                            ...                ...
# ClusterMean_Delaunay_MedianDistance       59.90691           5.155626
# ClusterMean_Delaunay_MaxDistance         98.409331          10.442108
# ClusterMean_Delaunay_MinDistance         34.928156           2.134182
# ClusterMean_Delaunay_MeanTriangleArea  1493.405442          267.10017
# ClusterMean_Delaunay_MaxTriangleArea   2866.164246         640.601194
#
#                                                                 \
#
#                                       Standard Deviation Error
# Feature
# CentroidXPx                                           3.628517
# CentroidYPx                                           3.297502
# Nucleus_Area                                          4.361925
# Nucleus_Perimeter                                     0.376889
# Nucleus_Circularity                                   0.001524
# ...                                                        ...
# ClusterMean_Delaunay_MedianDistance                   0.257781
# ClusterMean_Delaunay_MaxDistance                      0.522105
# ClusterMean_Delaunay_MinDistance                      0.106709
# ClusterMean_Delaunay_MeanTriangleArea                13.355009
# ClusterMean_Delaunay_MaxTriangleArea                  32.03006
#
#                                                             \
#
#                                       95% Upper Bound Mean
# Feature
# CentroidXPx                                    1009.618618
# CentroidYPx                                    1008.567376
# Nucleus_Area                                    574.627327
# Nucleus_Perimeter                                95.878277
# Nucleus_Circularity                               0.781776
# ...                                                    ...
# ClusterMean_Delaunay_MedianDistance               60.41153
# ClusterMean_Delaunay_MaxDistance                 99.431378
# ClusterMean_Delaunay_MinDistance                 35.137044
# ClusterMean_Delaunay_MeanTriangleArea          1519.548518
# ClusterMean_Delaunay_MaxTriangleArea           2928.864641
#
#                                                                     \
#                                                            Group C
#                                       95% Lower Bound Mean       N
# Feature
# CentroidXPx                                     995.412623    76.0
# CentroidYPx                                     995.657334    76.0
# Nucleus_Area                                    557.549967    76.0
# Nucleus_Perimeter                                94.402721    76.0
# Nucleus_Circularity                               0.775808    76.0
# ...                                                    ...     ...
# ClusterMean_Delaunay_MedianDistance              59.402291    76.0
# ClusterMean_Delaunay_MaxDistance                 97.387285    76.0
# ClusterMean_Delaunay_MinDistance                 34.719267    76.0
# ClusterMean_Delaunay_MeanTriangleArea          1467.262365    76.0
# ClusterMean_Delaunay_MaxTriangleArea           2803.463852    76.0
#
#                                                                        \
#
#                                               Mean Standard Deviation
# Feature
# CentroidXPx                              999.06698          94.041445
# CentroidYPx                            1006.882822          90.500594
# Nucleus_Area                            676.043737          79.690239
# Nucleus_Perimeter                       108.529616           6.817592
# Nucleus_Circularity                       0.712372           0.044852
# ...                                            ...                ...
# ClusterMean_Delaunay_MedianDistance      83.467883          11.972614
# ClusterMean_Delaunay_MaxDistance        151.673171          29.945072
# ClusterMean_Delaunay_MinDistance          41.12685           3.237495
# ClusterMean_Delaunay_MeanTriangleArea  2983.677591         913.061549
# ClusterMean_Delaunay_MaxTriangleArea   6562.873853        2513.138444
#
#                                                                 \
#
#                                       Standard Deviation Error
# Feature
# CentroidXPx                                          10.787294
# CentroidYPx                                           10.38113
# Nucleus_Area                                          9.141097
# Nucleus_Perimeter                                     0.782031
# Nucleus_Circularity                                   0.005145
# ...                                                        ...
# ClusterMean_Delaunay_MedianDistance                   1.373353
# ClusterMean_Delaunay_MaxDistance                      3.434935
# ClusterMean_Delaunay_MinDistance                      0.371366
# ClusterMean_Delaunay_MeanTriangleArea               104.735343
# ClusterMean_Delaunay_MaxTriangleArea                 288.27675
#
#                                                             \
#
#                                       95% Upper Bound Mean
# Feature
# CentroidXPx                                    1020.070515
# CentroidYPx                                    1027.095532
# Nucleus_Area                                    693.842025
# Nucleus_Perimeter                               110.052281
# Nucleus_Circularity                                0.72239
# ...                                                    ...
# ClusterMean_Delaunay_MedianDistance              86.141887
# ClusterMean_Delaunay_MaxDistance                158.361205
# ClusterMean_Delaunay_MinDistance                 41.849923
# ClusterMean_Delaunay_MeanTriangleArea          3187.603856
# ClusterMean_Delaunay_MaxTriangleArea           7124.166721
#
#
#
#                                       95% Lower Bound Mean
# Feature
# CentroidXPx                                     978.063444
# CentroidYPx                                     986.670112
# Nucleus_Area                                    658.245448
# Nucleus_Perimeter                               107.006952
# Nucleus_Circularity                               0.702355
# ...                                                    ...
# ClusterMean_Delaunay_MedianDistance              80.793879
# ClusterMean_Delaunay_MaxDistance                144.985137
# ClusterMean_Delaunay_MinDistance                 40.403777
# ClusterMean_Delaunay_MeanTriangleArea          2779.751326
# ClusterMean_Delaunay_MaxTriangleArea           6001.580984
#
# [494 rows x 19 columns]
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-195af0ab0cc4>", line 405, in Anova_table
#     root.mainloop()
# NameError: name 'root' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-195af0ab0cc4>", line 334, in clear_frame
#     self.w1.winfo_children()[7].destroy()
# IndexError: list index out of range
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-195af0ab0cc4>", line 334, in clear_frame
#     self.w1.winfo_children()[7].destroy()
# IndexError: list index out of range
#     Labels  Group A  Group B  Group C  Age  L/D Groups
# 0        2      0.0      1.0      0.0  361    1      2
# 1        6      1.0      0.0      0.0  481    1      1
# 2        7      1.0      0.0      0.0  481    1      1
# 3       19      0.0      1.0      0.0  506    1      2
# 4       24      1.0      0.0      0.0  401    1      1
# 5       31      1.0      0.0      0.0  244    1      1
# 6       32      1.0      0.0      0.0  244    1      1
# 7       66      1.0      1.0      0.0  286    1      2
# 8       81      0.0      1.0      0.0  281    1      2
# 9       88      1.0      0.0      0.0  129    1      1
# 10     122      1.0      0.0      0.0  323    1      1
# 11     504      1.0      0.0      0.0  156    1      1
# 12     514      0.0      0.0      1.0   36    1      3
# 13     577      0.0      1.0      0.0   76    1      2
# 14     613      1.0      0.0      0.0  114    1      1
# 15    1807      0.0      1.0      0.0  494    1      2
# 16    1813      1.0      0.0      0.0  545    1      1
# Iteration 1: norm_delta = 1.55587, step_size = 0.9000, log_lik = -33.50507, newton_decrement = 4.42735, seconds_since_start = 0.0
# Iteration 2: norm_delta = 1.00061, step_size = 0.9000, log_lik = -31.18455, newton_decrement = 1.23160, seconds_since_start = 0.0
# Iteration 3: norm_delta = 0.35227, step_size = 0.9000, log_lik = -30.72181, newton_decrement = 0.42883, seconds_since_start = 0.0
# Iteration 4: norm_delta = 0.01859, step_size = 1.0000, log_lik = -30.32007, newton_decrement = 0.00111, seconds_since_start = 0.0
# Iteration 5: norm_delta = 0.00027, step_size = 1.0000, log_lik = -30.31897, newton_decrement = 0.00000, seconds_since_start = 0.0
# Iteration 6: norm_delta = 0.00000, step_size = 1.0000, log_lik = -30.31897, newton_decrement = 0.00000, seconds_since_start = 0.0
# Convergence success after 6 iterations.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:344: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:346: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <lifelines.CoxPHFitter: fitted with 17 total observations, 0 right-censored observations>
#              duration col = 'Age'
#                 event col = 'L/D'
#                 penalizer = 0.1
#                  l1 ratio = 0.0
#       baseline estimation = breslow
#    number of observations = 17
# number of events observed = 17
#    partial log-likelihood = -30.32
#          time fit was run = 2022-05-02 11:49:12 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# Labels     -0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# Group A     0.22       1.25       0.89            -1.52             1.97                 0.22                 7.19
# Group B    -0.52       0.60       1.01            -2.50             1.47                 0.08                 4.34
# Group C     2.88      17.89       2.16            -1.36             7.12                 0.26              1241.36
# Groups      0.55       1.73       0.93            -1.28             2.38                 0.28                10.77
#
#               z    p   -log2(p)
# covariate
# Labels    -1.38 0.17       2.57
# Group A    0.25 0.80       0.32
# Group B   -0.51 0.61       0.71
# Group C    1.33 0.18       2.45
# Groups     0.59 0.56       0.85
# ---
# Concordance = 0.49
# Partial AIC = 70.64
# log-likelihood ratio test = 6.37 on 5 df
# -log2(p) of ll-ratio test = 1.88
# $\color{blue}{\Large Figure\ 0}$
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.7 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
